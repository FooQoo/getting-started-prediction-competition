# %%
import pandas as pd
import lightgbm as lgb
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, f1_score

df_train_origin = pd.read_csv('../data/train.csv')
df_test_origin = pd.read_csv('../data/test_leak.csv')
df_train_vecs = pd.read_csv('../fact/train_vecs.csv')
df_test_vecs = pd.read_csv('../fact/test_vecs.csv')

# %%
df_train = pd.merge(df_train_origin ,df_train_vecs, on='id')
df_test = pd.merge(df_test_origin ,df_test_vecs, on='id')

# %%
def get_c_with_prefix(train, prefix):
    return [column for column in train.columns.tolist() if prefix == column[:len(prefix)]]

c_vecs = get_c_with_prefix(df_train, 'vecs')

X_train, X_valid = df_train[c_vecs], df_test[c_vecs]
y_train, y_valid = df_train.target.values, df_test.target.values

lgb_train = lgb.Dataset(X_train, y_train)
lgb_valid = lgb.Dataset(X_valid, y_valid, reference=lgb_train)

def lgb_f1_score(y_hat, data):
    y_true = data.get_label()
    y_hat = np.round(y_hat) # scikits f1 doesn't like probabilities
    return 'f1', f1_score(y_true, y_hat, average=None)[0], True

lgbm_params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'verbosity': 4,
    'boosting_type': 'gbdt',
    'learning_rate': 0.1,
    'lambda_l1': 3.642434329823594, 
    'lambda_l2': 1.0401748765492007e-08, 
    'num_leaves': 172, 
    'feature_fraction': 0.8251431673667773, 
    'bagging_fraction': 0.9755605959841563, 
    'bagging_freq': 2, 
    'min_child_samples': 5, 
    'random_state': 68
}

model = lgb.train(
    lgbm_params, 
    lgb_train, 
    valid_sets=lgb_valid,
    verbose_eval=True,
    feval=lgb_f1_score,
    num_boost_round=300,
)

y_pred = model.predict(X_valid, num_iteration=model.best_iteration)
y_pred_cls = y_pred >= 0.5
print(f1_score(y_valid, y_pred_cls, average=None)[0])
# Out:
# [1]	valid_0's binary_logloss: 0.648545	valid_0's f1: 0.726386
# [2]	valid_0's binary_logloss: 0.619589	valid_0's f1: 0.812233
# [3]	valid_0's binary_logloss: 0.594569	valid_0's f1: 0.822656
# [4]	valid_0's binary_logloss: 0.574037	valid_0's f1: 0.828888
# [5]	valid_0's binary_logloss: 0.556387	valid_0's f1: 0.833413
# [6]	valid_0's binary_logloss: 0.542317	valid_0's f1: 0.834412
# [7]	valid_0's binary_logloss: 0.528954	valid_0's f1: 0.834057
# [8]	valid_0's binary_logloss: 0.516656	valid_0's f1: 0.8339
# [9]	valid_0's binary_logloss: 0.506989	valid_0's f1: 0.834146
# [10]	valid_0's binary_logloss: 0.498213	valid_0's f1: 0.836845
# [11]	valid_0's binary_logloss: 0.490351	valid_0's f1: 0.83738
# [12]	valid_0's binary_logloss: 0.483655	valid_0's f1: 0.838137
# [13]	valid_0's binary_logloss: 0.477269	valid_0's f1: 0.837117
# [14]	valid_0's binary_logloss: 0.472346	valid_0's f1: 0.836714
# [15]	valid_0's binary_logloss: 0.467249	valid_0's f1: 0.838119
# [16]	valid_0's binary_logloss: 0.463339	valid_0's f1: 0.838454
# [17]	valid_0's binary_logloss: 0.460001	valid_0's f1: 0.839574
# [18]	valid_0's binary_logloss: 0.45595	valid_0's f1: 0.840199
# [19]	valid_0's binary_logloss: 0.452914	valid_0's f1: 0.840486
# [20]	valid_0's binary_logloss: 0.450198	valid_0's f1: 0.84004
# [21]	valid_0's binary_logloss: 0.448523	valid_0's f1: 0.838998
# [22]	valid_0's binary_logloss: 0.446792	valid_0's f1: 0.839414
# [23]	valid_0's binary_logloss: 0.444958	valid_0's f1: 0.841191
# [24]	valid_0's binary_logloss: 0.443275	valid_0's f1: 0.841033
# [25]	valid_0's binary_logloss: 0.443103	valid_0's f1: 0.84153
# [26]	valid_0's binary_logloss: 0.442215	valid_0's f1: 0.840139
# [27]	valid_0's binary_logloss: 0.440978	valid_0's f1: 0.838565
# [28]	valid_0's binary_logloss: 0.440121	valid_0's f1: 0.837488
# [29]	valid_0's binary_logloss: 0.43889	valid_0's f1: 0.839143
# [30]	valid_0's binary_logloss: 0.438526	valid_0's f1: 0.839272
# [31]	valid_0's binary_logloss: 0.437808	valid_0's f1: 0.838903
# [32]	valid_0's binary_logloss: 0.437509	valid_0's f1: 0.838404
# [33]	valid_0's binary_logloss: 0.437898	valid_0's f1: 0.837534
# [34]	valid_0's binary_logloss: 0.437581	valid_0's f1: 0.837081
# [35]	valid_0's binary_logloss: 0.437718	valid_0's f1: 0.837824
# [36]	valid_0's binary_logloss: 0.438548	valid_0's f1: 0.837791
# [37]	valid_0's binary_logloss: 0.438368	valid_0's f1: 0.839241
# [38]	valid_0's binary_logloss: 0.438491	valid_0's f1: 0.838951
# [39]	valid_0's binary_logloss: 0.437946	valid_0's f1: 0.83974
# [40]	valid_0's binary_logloss: 0.43853	valid_0's f1: 0.84024
# [41]	valid_0's binary_logloss: 0.438892	valid_0's f1: 0.84024
# [42]	valid_0's binary_logloss: 0.439024	valid_0's f1: 0.83995
# [43]	valid_0's binary_logloss: 0.43964	valid_0's f1: 0.840449
# [44]	valid_0's binary_logloss: 0.439575	valid_0's f1: 0.841108
# [45]	valid_0's binary_logloss: 0.440054	valid_0's f1: 0.84011
# [46]	valid_0's binary_logloss: 0.440027	valid_0's f1: 0.84011
# [47]	valid_0's binary_logloss: 0.440659	valid_0's f1: 0.840189
# [48]	valid_0's binary_logloss: 0.440891	valid_0's f1: 0.840977
# [49]	valid_0's binary_logloss: 0.441791	valid_0's f1: 0.840399
# [50]	valid_0's binary_logloss: 0.442377	valid_0's f1: 0.839562
# [51]	valid_0's binary_logloss: 0.442727	valid_0's f1: 0.839112
# [52]	valid_0's binary_logloss: 0.443381	valid_0's f1: 0.84011
# [53]	valid_0's binary_logloss: 0.444302	valid_0's f1: 0.839032
# [54]	valid_0's binary_logloss: 0.445291	valid_0's f1: 0.839112
# [55]	valid_0's binary_logloss: 0.445339	valid_0's f1: 0.839032
# [56]	valid_0's binary_logloss: 0.44622	valid_0's f1: 0.838742
# [57]	valid_0's binary_logloss: 0.446717	valid_0's f1: 0.838871
# [58]	valid_0's binary_logloss: 0.447178	valid_0's f1: 0.83937
# [59]	valid_0's binary_logloss: 0.447967	valid_0's f1: 0.83908
# [60]	valid_0's binary_logloss: 0.448898	valid_0's f1: 0.83921
# [61]	valid_0's binary_logloss: 0.449505	valid_0's f1: 0.83871
# [62]	valid_0's binary_logloss: 0.450294	valid_0's f1: 0.839129
# [63]	valid_0's binary_logloss: 0.450493	valid_0's f1: 0.839049
# [64]	valid_0's binary_logloss: 0.451035	valid_0's f1: 0.84013
# [65]	valid_0's binary_logloss: 0.451503	valid_0's f1: 0.83929
# [66]	valid_0's binary_logloss: 0.452178	valid_0's f1: 0.837872
# [67]	valid_0's binary_logloss: 0.45287	valid_0's f1: 0.837872
# [68]	valid_0's binary_logloss: 0.452949	valid_0's f1: 0.838661
# [69]	valid_0's binary_logloss: 0.453607	valid_0's f1: 0.837791
# [70]	valid_0's binary_logloss: 0.454188	valid_0's f1: 0.837372
# [71]	valid_0's binary_logloss: 0.454723	valid_0's f1: 0.838452
# [72]	valid_0's binary_logloss: 0.455036	valid_0's f1: 0.83871
# [73]	valid_0's binary_logloss: 0.455822	valid_0's f1: 0.83871
# [74]	valid_0's binary_logloss: 0.455921	valid_0's f1: 0.83871
# [75]	valid_0's binary_logloss: 0.456313	valid_0's f1: 0.837919
# [76]	valid_0's binary_logloss: 0.4566	valid_0's f1: 0.837419
# [77]	valid_0's binary_logloss: 0.457126	valid_0's f1: 0.837337
# [78]	valid_0's binary_logloss: 0.457586	valid_0's f1: 0.838581
# [79]	valid_0's binary_logloss: 0.457749	valid_0's f1: 0.838371
# [80]	valid_0's binary_logloss: 0.458163	valid_0's f1: 0.838871
# [81]	valid_0's binary_logloss: 0.458955	valid_0's f1: 0.838419
# [82]	valid_0's binary_logloss: 0.459678	valid_0's f1: 0.840869
# [83]	valid_0's binary_logloss: 0.460097	valid_0's f1: 0.840869
# [84]	valid_0's binary_logloss: 0.460867	valid_0's f1: 0.8405
# [85]	valid_0's binary_logloss: 0.460795	valid_0's f1: 0.84092
# [86]	valid_0's binary_logloss: 0.460826	valid_0's f1: 0.84092
# [87]	valid_0's binary_logloss: 0.461576	valid_0's f1: 0.84063
# [88]	valid_0's binary_logloss: 0.46192	valid_0's f1: 0.84063
# [89]	valid_0's binary_logloss: 0.46292	valid_0's f1: 0.84013
# [90]	valid_0's binary_logloss: 0.463364	valid_0's f1: 0.84034
# [91]	valid_0's binary_logloss: 0.463717	valid_0's f1: 0.84034
# [92]	valid_0's binary_logloss: 0.463817	valid_0's f1: 0.839469
# [93]	valid_0's binary_logloss: 0.464278	valid_0's f1: 0.83976
# [94]	valid_0's binary_logloss: 0.46512	valid_0's f1: 0.840551
# [95]	valid_0's binary_logloss: 0.465548	valid_0's f1: 0.841051
# [96]	valid_0's binary_logloss: 0.466351	valid_0's f1: 0.841473
# [97]	valid_0's binary_logloss: 0.466766	valid_0's f1: 0.841262
# [98]	valid_0's binary_logloss: 0.467265	valid_0's f1: 0.841552
# [99]	valid_0's binary_logloss: 0.468241	valid_0's f1: 0.84171
# [100]	valid_0's binary_logloss: 0.468639	valid_0's f1: 0.841421
# [101]	valid_0's binary_logloss: 0.469662	valid_0's f1: 0.841631
# [102]	valid_0's binary_logloss: 0.470118	valid_0's f1: 0.842711
# [103]	valid_0's binary_logloss: 0.470814	valid_0's f1: 0.842132
# [104]	valid_0's binary_logloss: 0.471182	valid_0's f1: 0.841341
# [105]	valid_0's binary_logloss: 0.471574	valid_0's f1: 0.841552
# [106]	valid_0's binary_logloss: 0.471928	valid_0's f1: 0.841921
# [107]	valid_0's binary_logloss: 0.472077	valid_0's f1: 0.842132
# [108]	valid_0's binary_logloss: 0.472561	valid_0's f1: 0.841421
# [109]	valid_0's binary_logloss: 0.47294	valid_0's f1: 0.841341
# [110]	valid_0's binary_logloss: 0.473466	valid_0's f1: 0.841552
# [111]	valid_0's binary_logloss: 0.473987	valid_0's f1: 0.841552
# [112]	valid_0's binary_logloss: 0.474596	valid_0's f1: 0.840761
# [113]	valid_0's binary_logloss: 0.475098	valid_0's f1: 0.841051
# [114]	valid_0's binary_logloss: 0.476178	valid_0's f1: 0.84018
# [115]	valid_0's binary_logloss: 0.476476	valid_0's f1: 0.840892
# [116]	valid_0's binary_logloss: 0.476702	valid_0's f1: 0.840812
# [117]	valid_0's binary_logloss: 0.477077	valid_0's f1: 0.841103
# [118]	valid_0's binary_logloss: 0.477189	valid_0's f1: 0.842263
# [119]	valid_0's binary_logloss: 0.477415	valid_0's f1: 0.841842
# [120]	valid_0's binary_logloss: 0.477858	valid_0's f1: 0.841842
# [121]	valid_0's binary_logloss: 0.478074	valid_0's f1: 0.842421
# [122]	valid_0's binary_logloss: 0.47823	valid_0's f1: 0.842053
# [123]	valid_0's binary_logloss: 0.478484	valid_0's f1: 0.842632
# [124]	valid_0's binary_logloss: 0.4785	valid_0's f1: 0.841921
# [125]	valid_0's binary_logloss: 0.478586	valid_0's f1: 0.842579
# [126]	valid_0's binary_logloss: 0.478895	valid_0's f1: 0.843
# [127]	valid_0's binary_logloss: 0.479381	valid_0's f1: 0.843078
# [128]	valid_0's binary_logloss: 0.47918	valid_0's f1: 0.843367
# [129]	valid_0's binary_logloss: 0.479259	valid_0's f1: 0.843578
# [130]	valid_0's binary_logloss: 0.479485	valid_0's f1: 0.843578
# [131]	valid_0's binary_logloss: 0.480094	valid_0's f1: 0.8435
# [132]	valid_0's binary_logloss: 0.48041	valid_0's f1: 0.843289
# [133]	valid_0's binary_logloss: 0.480877	valid_0's f1: 0.843289
# [134]	valid_0's binary_logloss: 0.481423	valid_0's f1: 0.843422
# [135]	valid_0's binary_logloss: 0.481518	valid_0's f1: 0.842921
# [136]	valid_0's binary_logloss: 0.481849	valid_0's f1: 0.842921
# [137]	valid_0's binary_logloss: 0.482088	valid_0's f1: 0.843132
# [138]	valid_0's binary_logloss: 0.482466	valid_0's f1: 0.842843
# [139]	valid_0's binary_logloss: 0.482641	valid_0's f1: 0.843132
# [140]	valid_0's binary_logloss: 0.483102	valid_0's f1: 0.843343
# [141]	valid_0's binary_logloss: 0.483656	valid_0's f1: 0.843054
# [142]	valid_0's binary_logloss: 0.484262	valid_0's f1: 0.842843
# [143]	valid_0's binary_logloss: 0.484411	valid_0's f1: 0.842843
# [144]	valid_0's binary_logloss: 0.484616	valid_0's f1: 0.842263
# [145]	valid_0's binary_logloss: 0.484795	valid_0's f1: 0.841552
# [146]	valid_0's binary_logloss: 0.48504	valid_0's f1: 0.841421
# [147]	valid_0's binary_logloss: 0.485101	valid_0's f1: 0.841631
# [148]	valid_0's binary_logloss: 0.485176	valid_0's f1: 0.841631
# [149]	valid_0's binary_logloss: 0.485246	valid_0's f1: 0.842132
# [150]	valid_0's binary_logloss: 0.485493	valid_0's f1: 0.842132
# [151]	valid_0's binary_logloss: 0.486348	valid_0's f1: 0.841552
# [152]	valid_0's binary_logloss: 0.486827	valid_0's f1: 0.841552
# [153]	valid_0's binary_logloss: 0.487275	valid_0's f1: 0.841921
# [154]	valid_0's binary_logloss: 0.487462	valid_0's f1: 0.841631
# [155]	valid_0's binary_logloss: 0.487559	valid_0's f1: 0.841341
# [156]	valid_0's binary_logloss: 0.487805	valid_0's f1: 0.841631
# [157]	valid_0's binary_logloss: 0.487951	valid_0's f1: 0.841631
# [158]	valid_0's binary_logloss: 0.488203	valid_0's f1: 0.841131
# [159]	valid_0's binary_logloss: 0.488525	valid_0's f1: 0.840841
# [160]	valid_0's binary_logloss: 0.4886	valid_0's f1: 0.840761
# [161]	valid_0's binary_logloss: 0.48885	valid_0's f1: 0.840681
# [162]	valid_0's binary_logloss: 0.488858	valid_0's f1: 0.840471
# [163]	valid_0's binary_logloss: 0.489262	valid_0's f1: 0.840602
# [164]	valid_0's binary_logloss: 0.489648	valid_0's f1: 0.83997
# [165]	valid_0's binary_logloss: 0.489792	valid_0's f1: 0.83963
# [166]	valid_0's binary_logloss: 0.489791	valid_0's f1: 0.83976
# [167]	valid_0's binary_logloss: 0.489926	valid_0's f1: 0.84034
# [168]	valid_0's binary_logloss: 0.490015	valid_0's f1: 0.84026
# [169]	valid_0's binary_logloss: 0.489939	valid_0's f1: 0.84005
# [170]	valid_0's binary_logloss: 0.489939	valid_0's f1: 0.84021
# [171]	valid_0's binary_logloss: 0.490196	valid_0's f1: 0.84013
# [172]	valid_0's binary_logloss: 0.490316	valid_0's f1: 0.84013
# [173]	valid_0's binary_logloss: 0.490415	valid_0's f1: 0.84042
# [174]	valid_0's binary_logloss: 0.490882	valid_0's f1: 0.84
# [175]	valid_0's binary_logloss: 0.490874	valid_0's f1: 0.84
# [176]	valid_0's binary_logloss: 0.490768	valid_0's f1: 0.84
# [177]	valid_0's binary_logloss: 0.490824	valid_0's f1: 0.83971
# [178]	valid_0's binary_logloss: 0.490915	valid_0's f1: 0.83992
# [179]	valid_0's binary_logloss: 0.490726	valid_0's f1: 0.84005
# [180]	valid_0's binary_logloss: 0.491353	valid_0's f1: 0.84034
# [181]	valid_0's binary_logloss: 0.491414	valid_0's f1: 0.84034
# [182]	valid_0's binary_logloss: 0.491622	valid_0's f1: 0.84034
# [183]	valid_0's binary_logloss: 0.491859	valid_0's f1: 0.84092
# [184]	valid_0's binary_logloss: 0.491752	valid_0's f1: 0.84092
# [185]	valid_0's binary_logloss: 0.491811	valid_0's f1: 0.84063
# [186]	valid_0's binary_logloss: 0.491834	valid_0's f1: 0.84063
# [187]	valid_0's binary_logloss: 0.491965	valid_0's f1: 0.84034
# [188]	valid_0's binary_logloss: 0.492337	valid_0's f1: 0.84063
# [189]	valid_0's binary_logloss: 0.492349	valid_0's f1: 0.841421
# [190]	valid_0's binary_logloss: 0.492741	valid_0's f1: 0.84092
# [191]	valid_0's binary_logloss: 0.493161	valid_0's f1: 0.84092
# [192]	valid_0's binary_logloss: 0.493326	valid_0's f1: 0.84129
# [193]	valid_0's binary_logloss: 0.493422	valid_0's f1: 0.841
# [194]	valid_0's binary_logloss: 0.493473	valid_0's f1: 0.841
# [195]	valid_0's binary_logloss: 0.49389	valid_0's f1: 0.8415
# [196]	valid_0's binary_logloss: 0.494073	valid_0's f1: 0.8415
# [197]	valid_0's binary_logloss: 0.494057	valid_0's f1: 0.84171
# [198]	valid_0's binary_logloss: 0.494122	valid_0's f1: 0.84171
# [199]	valid_0's binary_logloss: 0.494026	valid_0's f1: 0.84121
# [200]	valid_0's binary_logloss: 0.493964	valid_0's f1: 0.84121
# [201]	valid_0's binary_logloss: 0.494074	valid_0's f1: 0.841631
# [202]	valid_0's binary_logloss: 0.494203	valid_0's f1: 0.842132
# [203]	valid_0's binary_logloss: 0.494206	valid_0's f1: 0.841552
# [204]	valid_0's binary_logloss: 0.494214	valid_0's f1: 0.841631
# [205]	valid_0's binary_logloss: 0.494283	valid_0's f1: 0.841631
# [206]	valid_0's binary_logloss: 0.494442	valid_0's f1: 0.841631
# [207]	valid_0's binary_logloss: 0.494537	valid_0's f1: 0.841631
# [208]	valid_0's binary_logloss: 0.494703	valid_0's f1: 0.841631
# [209]	valid_0's binary_logloss: 0.49498	valid_0's f1: 0.8415
# [210]	valid_0's binary_logloss: 0.495396	valid_0's f1: 0.84171
# [211]	valid_0's binary_logloss: 0.495519	valid_0's f1: 0.84171
# [212]	valid_0's binary_logloss: 0.495597	valid_0's f1: 0.84129
# [213]	valid_0's binary_logloss: 0.495713	valid_0's f1: 0.84129
# [214]	valid_0's binary_logloss: 0.495792	valid_0's f1: 0.84129
# [215]	valid_0's binary_logloss: 0.495857	valid_0's f1: 0.841
# [216]	valid_0's binary_logloss: 0.49613	valid_0's f1: 0.841
# [217]	valid_0's binary_logloss: 0.495997	valid_0's f1: 0.84071
# [218]	valid_0's binary_logloss: 0.495955	valid_0's f1: 0.84029
# [219]	valid_0's binary_logloss: 0.495983	valid_0's f1: 0.84058
# [220]	valid_0's binary_logloss: 0.495861	valid_0's f1: 0.841369
# [221]	valid_0's binary_logloss: 0.496153	valid_0's f1: 0.84129
# [222]	valid_0's binary_logloss: 0.496275	valid_0's f1: 0.8415
# [223]	valid_0's binary_logloss: 0.496208	valid_0's f1: 0.84079
# [224]	valid_0's binary_logloss: 0.49619	valid_0's f1: 0.84034
# [225]	valid_0's binary_logloss: 0.496396	valid_0's f1: 0.84063
# [226]	valid_0's binary_logloss: 0.496549	valid_0's f1: 0.840841
# [227]	valid_0's binary_logloss: 0.496744	valid_0's f1: 0.840841
# [228]	valid_0's binary_logloss: 0.49694	valid_0's f1: 0.840841
# [229]	valid_0's binary_logloss: 0.496974	valid_0's f1: 0.840551
# [230]	valid_0's binary_logloss: 0.497144	valid_0's f1: 0.840551
# [231]	valid_0's binary_logloss: 0.49747	valid_0's f1: 0.841262
# [232]	valid_0's binary_logloss: 0.49762	valid_0's f1: 0.841051
# [233]	valid_0's binary_logloss: 0.497525	valid_0's f1: 0.840761
# [234]	valid_0's binary_logloss: 0.497435	valid_0's f1: 0.840761
# [235]	valid_0's binary_logloss: 0.497983	valid_0's f1: 0.840841
# [236]	valid_0's binary_logloss: 0.498196	valid_0's f1: 0.8415
# [237]	valid_0's binary_logloss: 0.497969	valid_0's f1: 0.84063
# [238]	valid_0's binary_logloss: 0.498313	valid_0's f1: 0.84042
# [239]	valid_0's binary_logloss: 0.498418	valid_0's f1: 0.84079
# [240]	valid_0's binary_logloss: 0.498796	valid_0's f1: 0.84042
# [241]	valid_0's binary_logloss: 0.498796	valid_0's f1: 0.84042
# [242]	valid_0's binary_logloss: 0.498798	valid_0's f1: 0.84042
# [243]	valid_0's binary_logloss: 0.4988	valid_0's f1: 0.84042
# [244]	valid_0's binary_logloss: 0.499265	valid_0's f1: 0.84042
# [245]	valid_0's binary_logloss: 0.49938	valid_0's f1: 0.84063
# [246]	valid_0's binary_logloss: 0.499523	valid_0's f1: 0.840841
# [247]	valid_0's binary_logloss: 0.49966	valid_0's f1: 0.84121
# [248]	valid_0's binary_logloss: 0.499901	valid_0's f1: 0.84063
# [249]	valid_0's binary_logloss: 0.500025	valid_0's f1: 0.84092
# [250]	valid_0's binary_logloss: 0.500086	valid_0's f1: 0.84063
# [251]	valid_0's binary_logloss: 0.499957	valid_0's f1: 0.84063
# [252]	valid_0's binary_logloss: 0.500153	valid_0's f1: 0.84042
# [253]	valid_0's binary_logloss: 0.500476	valid_0's f1: 0.84034
# [254]	valid_0's binary_logloss: 0.50083	valid_0's f1: 0.83984
# [255]	valid_0's binary_logloss: 0.500935	valid_0's f1: 0.840551
# [256]	valid_0's binary_logloss: 0.50096	valid_0's f1: 0.84034
# [257]	valid_0's binary_logloss: 0.500958	valid_0's f1: 0.840841
# [258]	valid_0's binary_logloss: 0.500989	valid_0's f1: 0.840841
# [259]	valid_0's binary_logloss: 0.501222	valid_0's f1: 0.841131
# [260]	valid_0's binary_logloss: 0.501283	valid_0's f1: 0.84063
# [261]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [262]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [263]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [264]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [265]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [266]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [267]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [268]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [269]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [270]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [271]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [272]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [273]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [274]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [275]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [276]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [277]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [278]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [279]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [280]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [281]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [282]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [283]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [284]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [285]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [286]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [287]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [288]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [289]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [290]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [291]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [292]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [293]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [294]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [295]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [296]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [297]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [298]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [299]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# [300]	valid_0's binary_logloss: 0.501273	valid_0's f1: 0.841131
# 0.841130848136102

# %%
pd.DataFrame({'id': df_test.id, 'target': y_pred_cls.astype(int)}).to_csv('../output/submit.csv', index=None)
