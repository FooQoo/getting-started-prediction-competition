# %%
import pandas as pd

df_fn = pd.read_csv('../fact/fn.csv')

for doc in df_fn[['text','proba']].values.tolist():
    print(doc, '\n')
# Out:
# ["If you ever think you running out of choices in life rembr there's that kid that has no choice but wear a suicide bomb vest", 0.5581069690034102]
#
# ['Haley Lu Richardson Fights for Water in The Last Survivors (Review) http://t.co/oObSCFOKtQ', 0.5302735830769207]
#
# ["Have you ever seen the President \nwho killed your wounded child?\nOr the man that crashed your sister's plane \nclaimin' he was sent of God?", 0.6156755973282483]
#
# ['@olliebailey11 havnt you crashed ? ??', 0.516907196549402]
#
# ['Breast milk is the original #superfood but rates worldwide have stalled below 40% contributing to more than 800000 child deaths last year.', 0.585830496318313]
#
# ['Large rain drops falling in Rock Hill off Anderson Road. #rain #scwx #drought', 0.637553834618339]
#
# ['Fascinating pics from inside North Korea. Not propaganda not devastation - just people living life. http://t.co/E2Dbcpwd9u', 0.5668667552355169]
#
# ...

# %%
import pandas as pd

df_fn = pd.read_csv('../fact/fp.csv')

for doc in df_fn[['text', 'proba']].values.tolist():
    print(doc, '\n')
# Out:
# ["Coming later this year~ 'THE MAN THAT TATTOOED WOMEN.' A novel based on a real serial killer from #Arkansas &amp; a natural disaster. #NOLA", 0.4934429030370087]
#
# ["Russian nuclear-biological-chemical (NBC) brigade 'emergency response' exercise in Southern MD http://t.co/Ul5XdblmBk http://t.co/VjHpVLnbaw", 0.3812192269896397]
#
# ["Short of throwing them overboard himself I don't think any other leader could do much worse by #refugees than @TonyAbbottMHR worst pm ever!", 0.3808778238966645]
#
# ['Carterville High School coaches prepare for game-day injuries http://t.co/kKiMMBUe04', 0.3480939148618439]
#
# ["@violentfeminazi I guess that's ok for Armenians since we've spent most of our history getting annihilated", 0.3411202675167327]
#
# ['@HaydnExists so glad i saved them all at once then didn\x89Ûªt want you stealing my thunder :P', 0.30169886131200563]
#
# ['What is this? Like I could be in danger or something', 0.29258793581394044]
#
# ...
