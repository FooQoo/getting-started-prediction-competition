# %%
import pandas as pd

df = pd.read_csv('../file/train_clean.tsv', sep='\t')

# %%
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# 5         8     NaN      NaN
# 6        10     NaN      NaN
# 7        13     NaN      NaN
# 8        14     NaN      NaN
# 9        15     NaN      NaN
# 10       16     NaN      NaN
# 11       17     NaN      NaN
# 12       18     NaN      NaN
# 13       19     NaN      NaN
# 14       20     NaN      NaN
# 15       23     NaN      NaN
# 16       24     NaN      NaN
# 17       25     NaN      NaN
# 18       26     NaN      NaN
# 19       28     NaN      NaN
# 20       31     NaN      NaN
# 21       32     NaN      NaN
# 22       33     NaN      NaN
# 23       34     NaN      NaN
# 24       36     NaN      NaN
# 25       37     NaN      NaN
# 26       38     NaN      NaN
# 27       39     NaN      NaN
# 28       40     NaN      NaN
# 29       41     NaN      NaN
# ...     ...     ...      ...
# ...
